# %% [markdown]
# <center><font size = "10"> Week 5 - Single Cell Electrophysiology<center>
# <center><font size = "8">Tutorial 02: Analysis<center>

# %% [markdown]
# <font size = "3"><font color = "blue"> In this tutorial you will analyse real single cell voltage recordings

# %%
# Load usefull packages
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import csv
import pandas as pd

# %% [markdown]
# # 1. Open files with traces

# %% [markdown]
# ### Traces description
#
# <font size='3'>Here we have some traces (exp_FirePatter_ch(6/7)_(52/53).dat). Ch6 contains the voltage response and Ch7 the current stimulation. The numbers 52 and 53 represent different "sweeps", so different repetitions of the same stimulation over the same cell.

# %%
# Open and plot files

def get_data(fn):
    """Read  data file and formatfor plotting"""
    d = np.fromfile(fn)    
    return d[::2], d[1::2]

file_v1 = "exp_FirePattern_ch6_52.dat"
file_v2 = "exp_FirePattern_ch6_53.dat"

FILE_v = [file_v1, file_v2] 


plt.figure(figsize=(15,3))
for fv in FILE_v:
    t, v = get_data(fv)
    plt.plot(t,v)

# %% [markdown]
# # 2. Extracting peaks, peak times and amplitude for one sweep

# %%
from scipy.signal import find_peaks, peak_prominences

t, v = get_data(file_v1)

# Amplitudes and peak locations
peaks_time, _ = find_peaks(v, prominence=1, height=-20)
amplitudes = peak_prominences(v, peaks_time, wlen=40)[0]

voltage_peaks = []
for x in peaks_time:
    volt_p = v[x]
    voltage_peaks.append(volt_p)
    
#Print results   
print("Voltage peaks: %s" %voltage_peaks)
print('\n')
print ("Amplitudes of action potentials: %s " % amplitudes)
print('\n')
print("Times of peak occurences: %s" % peaks_time)

# Plot
plt.figure(figsize=(15,3))
plt.plot(v,'k--')
plt.plot(peaks_time, v[peaks_time], 'rx')
plt.ylabel('voltage (mV)')
# Out:
# Voltage peaks: [13.918750762939453, 13.956249237060547, 13.524999618530273, 13.83125114440918, 13.9375, 14.443750381469727, 14.26875114440918, 14.637500762939453, 14.537500381469727, 13.75, 14.287500381469727, 14.043750762939453, 13.956249237060547, 14.5, 14.631250381469727, 13.256250381469727, 13.368749618530273, 13.09375, 13.631248474121094, 14.200000762939453, 14.174999237060547, 13.899999618530273, 13.69999885559082, 13.868749618530273, 13.931251525878906, 13.993749618530273, 14.100000381469727, 13.850000381469727, 13.837499618530273, 13.98124885559082]
#
#
# Amplitudes of action potentials: [63.44375229 63.59999847 64.22500038 64.43125343 63.80624771 64.24374962
#  63.39999962 62.66875076 63.33125114 63.36874771 64.05624962 63.10625076
#  63.43125153 63.1875     62.98750114 63.63749886 64.03750038 62.61249924
#  63.52499771 63.30000305 63.11249924 63.33125114 63.36874962 62.80000114
#  63.40000153 63.38125038 63.26250267 62.86874962 63.35624886 64.09999657]
#
#
# Times of peak occurences: [ 3789  5039  6166  7248  8441  9552 10727 11927 13136 14338 15462 16483
#  17564 18738 20077 21227 22287 23292 24363 25439 26623 27896 29047 30238
#  31505 32854 34147 35504 36813 38050]
# Text(0, 0.5, 'voltage (mV)')

# %% [markdown]
# # 3. Using a specific library: eFEL
#
# <font size = "3">Find the documentation [here](https://readthedocs.org/projects/efel/downloads/pdf/latest/)
#
# <font size='3'>We will use the getFeatureValues() function, which accepts as input a dictionary that represents the trace, and the request eFeature names. The trace dictionary consists of the time and voltage trace, and two floats stim_start and stim_end that specify when the stimulus starts and stops.

# %%
file_c1 = "exp_FirePattern_ch7_52.dat"

t, v = get_data(file_v1)
t, i = get_data(file_c1)

# Look for start and end time
peaks_time, _ = find_peaks(i, prominence=1, height=-20)

print(np.min(peaks_time))
print(np.max(peaks_time))
# Out:
# 3785
# 36810

# %%
import efel
from json2html import *
import IPython

stim_start = 378.9 # in ms
stim_end = 3681.0
trace = {'T': t, 'V': v, 'stim_start': [stim_start], 'stim_end': [stim_end]}

# %%
feature_values = efel.getFeatureValues([trace], ['AP_amplitude', 'peak_time', 'peak_voltage'])[0]
feature_values = {feature_name: list(values) for feature_name, values in feature_values.items()}
IPython.display.HTML(json2html.convert(json=feature_values))
# Out:
# <table border="1"><tr><th>AP_amplitude</th><td><ul><li>61.84374999828267</li><li>63.27500152426446</li><li>62.90624808976966</li><li>61.61250113941944</li><li>62.09999847056085</li><li>62.649999614468335</li><li>61.49374961750402</li><li>61.44375229011517</li><li>62.41875267308183</li><li>61.68749999780155</li><li>62.543748856962814</li><li>61.89374923688065</li><li>62.21249771247033</li><li>61.837501526743715</li><li>62.806249625738495</li><li>62.350000393304</li><li>61.67500115657589</li><li>61.97499845443609</li><li>61.65624617381701</li><li>62.306251513255404</li><li>63.16250227262316</li><li>62.843748071199286</li><li>63.081247309400304</li><li>61.75000189435543</li><li>61.525001543548775</li><li>61.8437480991301</li><li>62.556249609155195</li><li>62.83750340796261</li></ul></td></tr><tr><th>peak_time</th><td><ul><li>378.90000000001766</li><li>503.9000000000461</li><li>616.6000000000716</li><li>724.8000000000962</li><li>844.1000000001234</li><li>955.2000000001486</li><li>1072.7000000001199</li><li>1192.7000000000107</li><li>1313.5999999999008</li><li>1433.7999999997915</li><li>1546.1999999996892</li><li>1648.2999999995964</li><li>1756.399999999498</li><li>1873.7999999993913</li><li>2007.6999999992695</li><li>2122.699999999165</li><li>2228.6999999990685</li><li>2329.199999998977</li><li>2436.2999999988797</li><li>2543.899999998782</li><li>2662.299999998674</li><li>2789.5999999985584</li><li>2904.6999999984537</li><li>3023.7999999983454</li><li>3150.49999999823</li><li>3285.3999999981074</li><li>3414.69999999799</li><li>3550.3999999978664</li><li>3681.2999999977474</li><li>3804.999999997635</li></ul></td></tr><tr><th>peak_voltage</th><td><ul><li>13.918750762563896</li><li>13.956249237034648</li><li>13.524999617303735</li><li>13.83125114345941</li><li>13.937499999814973</li><li>14.443750379565934</li><li>14.268751143577884</li><li>14.637500762888692</li><li>14.537500381302054</li><li>13.749999994351272</li><li>14.287500379643655</li><li>14.04375075796747</li><li>13.956249233295239</li><li>14.499999991513356</li><li>14.631250377725644</li><li>13.256250381260887</li><li>13.368749615618487</li><li>13.093749972757788</li><li>13.631248454722515</li><li>14.20000074161976</li><li>14.174999211948613</li><li>13.899999587707457</li><li>13.699998825045578</li><li>13.868749580986398</li><li>13.93125152167543</li><li>13.993749607174351</li><li>14.100000358098377</li><li>13.850000344663831</li><li>13.837499565166647</li><li>13.981248820409366</li></ul></td></tr></table>
